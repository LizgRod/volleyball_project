# %%
# Importing needed packages

import pandas as pd
import numpy as np
import scipy
from itertools import islice
from collections import Counter
import matplotlib.pyplot as plt
import csv
import math
import warnings
from sklearn.linear_model import LinearRegression

# %%
vr_data = pd.read_csv('vrnewdata.csv')

# %%
vr_data.head(5)
# Out:
#                          Date  \
# 0               Enter a date:
# 1  {"ImportId":"QID102_TEXT"}
# 2                     2/14/23
# 3                     2/14/23
# 4                     2/14/23
#
#                                    Identifier.Number  \
# 0  Identifier Number: This is a three-letter and ...
# 1                          {"ImportId":"QID43_TEXT"}
# 2                                        PJM02142023
# 3                                        PAW02142023
# 4                                        PIC02142023
#
#                       Haptic  \
# 0  0 = No Haptic, 1 = Haptic
# 1                        NaN
# 2                          1
# 3                          1
# 4                          1
#
#                                  Emotions.Baseline_1  \
# 0  Sometimes emotional state can influence learni...
# 1                            {"ImportId":"QID104_1"}
# 2                                         4 Somewhat
# 3                                         5 Somewhat
# 4                                         5 Somewhat
#
#                                  Emotions.Baseline_2  \
# 0  Sometimes emotional state can influence learni...
# 1                            {"ImportId":"QID104_2"}
# 2                                       1 Not at all
# 3                                       1 Not at all
# 4                                       1 Not at all
#
#                                  Emotions.Baseline_3  \
# 0  Sometimes emotional state can influence learni...
# 1                            {"ImportId":"QID104_3"}
# 2                                       1 Not at all
# 3                                         6 Somewhat
# 4                                       1 Not at all
#
#                                  Emotions.Baseline_4  \
# 0  Sometimes emotional state can influence learni...
# 1                            {"ImportId":"QID104_4"}
# 2                                       1 Not at all
# 3                                         5 Somewhat
# 4                                       1 Not at all
#
#                                  Emotions.Baseline_5  \
# 0  Sometimes emotional state can influence learni...
# 1                            {"ImportId":"QID104_5"}
# 2                                       1 Not at all
# 3                                       3 Not at all
# 4                                         5 Somewhat
#
#                                  Emotions.Baseline_6  \
# 0  Sometimes emotional state can influence learni...
# 1                            {"ImportId":"QID104_6"}
# 2                                       1 Not at all
# 3                                       1 Not at all
# 4                                       1 Not at all
#
#                                  Emotions.Baseline_7  ...  \
# 0  Sometimes emotional state can influence learni...  ...
# 1                            {"ImportId":"QID104_7"}  ...
# 2                                       1 Not at all  ...
# 3                                       1 Not at all  ...
# 4                                       1 Not at all  ...
#
#                                Injury.Witness  \
# 0  Have you seen someone get injured at work?
# 1                        {"ImportId":"QID92"}
# 2                                         Yes
# 3                                         Yes
# 4                                          No
#
#                                     Witness.Severity  \
# 0  In light of your previous response, what was t...
# 1                               {"ImportId":"QID93"}
# 2                  Critical (disabling/fatal injury)
# 3                           Minor (first aid injury)
# 4                                                NaN
#
#                          Age                              Const.Experience  \
# 0                        Age  Years of experience in construction industry
# 1  {"ImportId":"QID94_TEXT"}                     {"ImportId":"QID95_TEXT"}
# 2                         40                                            15
# 3                         21                                        1 year
# 4                         20                                             1
#
#                                                 Role  \
# 0  What role does best descrive your involvement ...
# 1                               {"ImportId":"QID96"}
# 2                       Leadership and/or management
# 3                                            Student
# 4                           Field worker (any trade)
#
#                                          Role_4_TEXT  \
# 0  What role does best descrive your involvement ...
# 1                        {"ImportId":"QID96_4_TEXT"}
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                               Education                Gender  \
# 0  Highest level of education completed                Gender
# 1             {"ImportId":"QID97_TEXT"}  {"ImportId":"QID98"}
# 2                           Hs diploma                   Male
# 3                             Bachelors                Female
# 4                          High school                   Male
#
#                      Ethnicity                          Ethnicity_21_TEXT
# 0  Ethnicity - Selected Choice  Ethnicity - Other (Please specify) - Text
# 1         {"ImportId":"QID99"}               {"ImportId":"QID99_21_TEXT"}
# 2                        White                                        NaN
# 3        White,Hispanic/LatinX                                        NaN
# 4                        White                                        NaN
#
# [5 rows x 212 columns]

# %%
# Checking values in Loop Columns - Yes or No
unique_vals_hazard1 = vr_data['3_Loop'].unique().tolist()
unique_vals_hazard1
# Out:
# ['Hazard 3 - Would you like to list another hazard?',
#  '{"ImportId":"3_QID66"}',
#  nan,
#  'Yes',
#  'No']

# %%
# Counting the number of hazards identified for the first picture shown for each participant

vr_data['pic1_yes'] = 0

for index, row in vr_data.iterrows():
    
    if row.iloc[37] == 'Yes':
        vr_data.at[index, 'pic1_yes'] += 1
    
    if row.iloc[40] == 'Yes':
        vr_data.at[index, 'pic1_yes'] += 1
    
    if row.iloc[43] == 'Yes':
        vr_data.at[index, 'pic1_yes'] += 1
        
    if row.iloc[46] == 'Yes':
        vr_data.at[index, 'pic1_yes'] += 1
    
    if row.iloc[49] == 'Yes':
        vr_data.at[index, 'pic1_yes'] += 1
        
    if row.iloc[52] == 'Yes':
        vr_data.at[index, 'pic1_yes'] += 1
    
    if row.iloc[55] == 'Yes':
        vr_data.at[index, 'pic1_yes'] += 1
        
    if row.iloc[58] == 'Yes':
        vr_data.at[index, 'pic1_yes'] += 1

# %%
#vr_data

# %%
# Counting the number of hazards identified for the second picture shown for each participant

vr_data['pic2_yes'] = 0

for index, row in vr_data.iterrows():
    
    if row.iloc[65] == 'Yes':
        vr_data.at[index, 'pic2_yes'] += 1
    
    if row.iloc[68] == 'Yes':
        vr_data.at[index, 'pic2_yes'] += 1
    
    if row.iloc[71] == 'Yes':
        vr_data.at[index, 'pic2_yes'] += 1
        
    if row.iloc[74] == 'Yes':
        vr_data.at[index, 'pic2_yes'] += 1
    
    if row.iloc[77] == 'Yes':
        vr_data.at[index, 'pic2_yes'] += 1
        
    if row.iloc[80] == 'Yes':
        vr_data.at[index, 'pic2_yes'] += 1
    
    if row.iloc[83] == 'Yes':
        vr_data.at[index, 'pic2_yes'] += 1
        
    if row.iloc[86] == 'Yes':
        vr_data.at[index, 'pic2_yes'] += 1
        
    if row.iloc[89] == 'Yes':
        vr_data.at[index, 'pic2_yes'] += 1
        
    if row.iloc[92] == 'Yes':
        vr_data.at[index, 'pic2_yes'] += 1
        
    if row.iloc[95] == 'Yes':
        vr_data.at[index, 'pic2_yes'] += 1
    
    if row.iloc[98] == 'Yes':
        vr_data.at[index, 'pic2_yes'] += 1
        
    if row.iloc[101] == 'Yes':
        vr_data.at[index, 'pic2_yes'] += 1
        
    if row.iloc[104] == 'Yes':
        vr_data.at[index, 'pic2_yes'] += 1

# %%
#vr_data

# %%
# Counting the number of hazards identified for the third picture shown for each participant

vr_data['pic3_yes'] = 0

for index, row in vr_data.iterrows():
    
    if row.iloc[143] == 'Yes':
        vr_data.at[index, 'pic3_yes'] += 1
    
    if row.iloc[146] == 'Yes':
        vr_data.at[index, 'pic3_yes'] += 1
    
    if row.iloc[149] == 'Yes':
        vr_data.at[index, 'pic3_yes'] += 1
        
    if row.iloc[152] == 'Yes':
        vr_data.at[index, 'pic3_yes'] += 1
    
    if row.iloc[155] == 'Yes':
        vr_data.at[index, 'pic3_yes'] += 1
        
    if row.iloc[158] == 'Yes':
        vr_data.at[index, 'pic3_yes'] += 1
    
    if row.iloc[161] == 'Yes':
        vr_data.at[index, 'pic3_yes'] += 1
        
    if row.iloc[164] == 'Yes':
        vr_data.at[index, 'pic3_yes'] += 1
        
    if row.iloc[167] == 'Yes':
        vr_data.at[index, 'pic3_yes'] += 1
        
    if row.iloc[170] == 'Yes':
        vr_data.at[index, 'pic3_yes'] += 1
        
    if row.iloc[173] == 'Yes':
        vr_data.at[index, 'pic3_yes'] += 1
    
    if row.iloc[176] == 'Yes':
        vr_data.at[index, 'pic3_yes'] += 1
        
    if row.iloc[179] == 'Yes':
        vr_data.at[index, 'pic3_yes'] += 1
        
    if row.iloc[182] == 'Yes':
        vr_data.at[index, 'pic3_yes'] += 1
        
    if row.iloc[185] == 'Yes':
        vr_data.at[index, 'pic3_yes'] += 1
        
    if row.iloc[188] == 'Yes':
        vr_data.at[index, 'pic3_yes'] += 1
        
    if row.iloc[191] == 'Yes':
        vr_data.at[index, 'pic3_yes'] += 1

# %%
vr_data
# Out:
#                           Date  \
# 0                Enter a date:
# 1   {"ImportId":"QID102_TEXT"}
# 2                      2/14/23
# 3                      2/14/23
# 4                      2/14/23
# ..                         ...
# 84                     3/30/23
# 85                     3/30/23
# 86                     3/30/23
# 87                     3/30/23
# 88                     3/30/23
#
#                                     Identifier.Number  \
# 0   Identifier Number: This is a three-letter and ...
# 1                           {"ImportId":"QID43_TEXT"}
# 2                                         PJM02142023
# 3                                         PAW02142023
# 4                                         PIC02142023
# ..                                                ...
# 84                                        PGB03302023
# 85                                        PGH03302023
# 86                                        PAS03302023
# 87                                        PJJ03302023
# 88                                        PTJ03302023
#
#                        Haptic  \
# 0   0 = No Haptic, 1 = Haptic
# 1                         NaN
# 2                           1
# 3                           1
# 4                           1
# ..                        ...
# 84                          0
# 85                          0
# 86                          0
# 87                          0
# 88                          0
#
#                                   Emotions.Baseline_1  \
# 0   Sometimes emotional state can influence learni...
# 1                             {"ImportId":"QID104_1"}
# 2                                          4 Somewhat
# 3                                          5 Somewhat
# 4                                          5 Somewhat
# ..                                                ...
# 84                                         6 Somewhat
# 85                                         4 Somewhat
# 86                                       1 Not at all
# 87                                         5 Somewhat
# 88                                         4 Somewhat
#
#                                   Emotions.Baseline_2  \
# 0   Sometimes emotional state can influence learni...
# 1                             {"ImportId":"QID104_2"}
# 2                                        1 Not at all
# 3                                        1 Not at all
# 4                                        1 Not at all
# ..                                                ...
# 84                                       3 Not at all
# 85                                       1 Not at all
# 86                                       1 Not at all
# 87                                       1 Not at all
# 88                                       1 Not at all
#
#                                   Emotions.Baseline_3  \
# 0   Sometimes emotional state can influence learni...
# 1                             {"ImportId":"QID104_3"}
# 2                                        1 Not at all
# 3                                          6 Somewhat
# 4                                        1 Not at all
# ..                                                ...
# 84                                       1 Not at all
# 85                                         4 Somewhat
# 86                                       1 Not at all
# 87                                       3 Not at all
# 88                                       1 Not at all
#
#                                   Emotions.Baseline_4  \
# 0   Sometimes emotional state can influence learni...
# 1                             {"ImportId":"QID104_4"}
# 2                                        1 Not at all
# 3                                          5 Somewhat
# 4                                        1 Not at all
# ..                                                ...
# 84                                       1 Not at all
# 85                                         4 Somewhat
# 86                                       1 Not at all
# 87                                       1 Not at all
# 88                                       1 Not at all
#
#                                   Emotions.Baseline_5  \
# 0   Sometimes emotional state can influence learni...
# 1                             {"ImportId":"QID104_5"}
# 2                                        1 Not at all
# 3                                        3 Not at all
# 4                                          5 Somewhat
# ..                                                ...
# 84                                         6 Somewhat
# 85                                       1 Not at all
# 86                                       1 Not at all
# 87                                       3 Not at all
# 88                                       1 Not at all
#
#                                   Emotions.Baseline_6  \
# 0   Sometimes emotional state can influence learni...
# 1                             {"ImportId":"QID104_6"}
# 2                                        1 Not at all
# 3                                        1 Not at all
# 4                                        1 Not at all
# ..                                                ...
# 84                                       1 Not at all
# 85                                       1 Not at all
# 86                                       1 Not at all
# 87                                       1 Not at all
# 88                                       1 Not at all
#
#                                   Emotions.Baseline_7  ...  \
# 0   Sometimes emotional state can influence learni...  ...
# 1                             {"ImportId":"QID104_7"}  ...
# 2                                        1 Not at all  ...
# 3                                        1 Not at all  ...
# 4                                        1 Not at all  ...
# ..                                                ...  ...
# 84                                       1 Not at all  ...
# 85                                         4 Somewhat  ...
# 86                                       1 Not at all  ...
# 87                                                NaN  ...
# 88                                       1 Not at all  ...
#
#                                 Const.Experience  \
# 0   Years of experience in construction industry
# 1                      {"ImportId":"QID95_TEXT"}
# 2                                             15
# 3                                         1 year
# 4                                              1
# ..                                           ...
# 84                                       3 years
# 85                                            20
# 86                                             4
# 87                                             5
# 88                                             5
#
#                                                  Role  \
# 0   What role does best descrive your involvement ...
# 1                                {"ImportId":"QID96"}
# 2                        Leadership and/or management
# 3                                             Student
# 4                            Field worker (any trade)
# ..                                                ...
# 84                           Field worker (any trade)
# 85                           Field worker (any trade)
# 86                           Field worker (any trade)
# 87                           Field worker (any trade)
# 88                           Field worker (any trade)
#
#                                           Role_4_TEXT  \
# 0   What role does best descrive your involvement ...
# 1                         {"ImportId":"QID96_4_TEXT"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 84                                                NaN
# 85                                                NaN
# 86                                                NaN
# 87                                                NaN
# 88                                                NaN
#
#                                Education                Gender  \
# 0   Highest level of education completed                Gender
# 1              {"ImportId":"QID97_TEXT"}  {"ImportId":"QID98"}
# 2                            Hs diploma                   Male
# 3                              Bachelors                Female
# 4                           High school                   Male
# ..                                   ...                   ...
# 84                           High school                  Male
# 85                              12 grade                  Male
# 86       3yrs community college(Nursing)                  Male
# 87                          High school                   Male
# 88                       College 2 years                Female
#
#                               Ethnicity  \
# 0           Ethnicity - Selected Choice
# 1                  {"ImportId":"QID99"}
# 2                                 White
# 3                 White,Hispanic/LatinX
# 4                                 White
# ..                                  ...
# 84  Native Hawaiian or Pacific Islander
# 85                                White
# 86                      Hispanic/LatinX
# 87                      Hispanic/LatinX
# 88            Black or African American
#
#                             Ethnicity_21_TEXT pic1_yes pic2_yes pic3_yes
# 0   Ethnicity - Other (Please specify) - Text        0        0        0
# 1                {"ImportId":"QID99_21_TEXT"}        0        0        0
# 2                                         NaN        1        2        2
# 3                                         NaN        1        2        3
# 4                                         NaN        0        1        0
# ..                                        ...      ...      ...      ...
# 84                                        NaN        0        0        0
# 85                                        NaN        0        3        0
# 86                                        NaN        0        3        1
# 87                                        NaN        2        2        0
# 88                                        NaN        1        3        0
#
# [89 rows x 215 columns]

# %%
# Exporting updated dataframe with counts of hazards for each participant

vr_data.to_csv('vrdata_1', index = False)

# %%
# Reading in the new dataframe with one added to each participants count if they originally identified a hazard

vr_data2 = pd.read_csv('vrdata_2.csv')

# %%
vr_data2
# Out:
#                           Date  \
# 0                Enter a date:
# 1   {"ImportId":"QID102_TEXT"}
# 2                      2/14/23
# 3                      2/14/23
# 4                      2/14/23
# ..                         ...
# 84                     3/30/23
# 85                     3/30/23
# 86                     3/30/23
# 87                     3/30/23
# 88                     3/30/23
#
#                                     Identifier.Number  \
# 0   Identifier Number: This is a three-letter and ...
# 1                           {"ImportId":"QID43_TEXT"}
# 2                                         PJM02142023
# 3                                         PAW02142023
# 4                                         PIC02142023
# ..                                                ...
# 84                                        PGB03302023
# 85                                        PGH03302023
# 86                                        PAS03302023
# 87                                        PJJ03302023
# 88                                        PTJ03302023
#
#                        Haptic  \
# 0   0 = No Haptic, 1 = Haptic
# 1                         NaN
# 2                           1
# 3                           1
# 4                           1
# ..                        ...
# 84                          0
# 85                          0
# 86                          0
# 87                          0
# 88                          0
#
#                                   Emotions.Baseline_1  \
# 0   Sometimes emotional state can influence learni...
# 1                             {"ImportId":"QID104_1"}
# 2                                          4 Somewhat
# 3                                          5 Somewhat
# 4                                          5 Somewhat
# ..                                                ...
# 84                                         6 Somewhat
# 85                                         4 Somewhat
# 86                                       1 Not at all
# 87                                         5 Somewhat
# 88                                         4 Somewhat
#
#                                   Emotions.Baseline_2  \
# 0   Sometimes emotional state can influence learni...
# 1                             {"ImportId":"QID104_2"}
# 2                                        1 Not at all
# 3                                        1 Not at all
# 4                                        1 Not at all
# ..                                                ...
# 84                                       3 Not at all
# 85                                       1 Not at all
# 86                                       1 Not at all
# 87                                       1 Not at all
# 88                                       1 Not at all
#
#                                   Emotions.Baseline_3  \
# 0   Sometimes emotional state can influence learni...
# 1                             {"ImportId":"QID104_3"}
# 2                                        1 Not at all
# 3                                          6 Somewhat
# 4                                        1 Not at all
# ..                                                ...
# 84                                       1 Not at all
# 85                                         4 Somewhat
# 86                                       1 Not at all
# 87                                       3 Not at all
# 88                                       1 Not at all
#
#                                   Emotions.Baseline_4  \
# 0   Sometimes emotional state can influence learni...
# 1                             {"ImportId":"QID104_4"}
# 2                                        1 Not at all
# 3                                          5 Somewhat
# 4                                        1 Not at all
# ..                                                ...
# 84                                       1 Not at all
# 85                                         4 Somewhat
# 86                                       1 Not at all
# 87                                       1 Not at all
# 88                                       1 Not at all
#
#                                   Emotions.Baseline_5  \
# 0   Sometimes emotional state can influence learni...
# 1                             {"ImportId":"QID104_5"}
# 2                                        1 Not at all
# 3                                        3 Not at all
# 4                                          5 Somewhat
# ..                                                ...
# 84                                         6 Somewhat
# 85                                       1 Not at all
# 86                                       1 Not at all
# 87                                       3 Not at all
# 88                                       1 Not at all
#
#                                   Emotions.Baseline_6  \
# 0   Sometimes emotional state can influence learni...
# 1                             {"ImportId":"QID104_6"}
# 2                                        1 Not at all
# 3                                        1 Not at all
# 4                                        1 Not at all
# ..                                                ...
# 84                                       1 Not at all
# 85                                       1 Not at all
# 86                                       1 Not at all
# 87                                       1 Not at all
# 88                                       1 Not at all
#
#                                   Emotions.Baseline_7  ...  \
# 0   Sometimes emotional state can influence learni...  ...
# 1                             {"ImportId":"QID104_7"}  ...
# 2                                        1 Not at all  ...
# 3                                        1 Not at all  ...
# 4                                        1 Not at all  ...
# ..                                                ...  ...
# 84                                       1 Not at all  ...
# 85                                         4 Somewhat  ...
# 86                                       1 Not at all  ...
# 87                                                NaN  ...
# 88                                       1 Not at all  ...
#
#                                 Const.Experience  \
# 0   Years of experience in construction industry
# 1                      {"ImportId":"QID95_TEXT"}
# 2                                             15
# 3                                         1 year
# 4                                              1
# ..                                           ...
# 84                                       3 years
# 85                                            20
# 86                                             4
# 87                                             5
# 88                                             5
#
#                                                  Role  \
# 0   What role does best descrive your involvement ...
# 1                                {"ImportId":"QID96"}
# 2                        Leadership and/or management
# 3                                             Student
# 4                            Field worker (any trade)
# ..                                                ...
# 84                           Field worker (any trade)
# 85                           Field worker (any trade)
# 86                           Field worker (any trade)
# 87                           Field worker (any trade)
# 88                           Field worker (any trade)
#
#                                           Role_4_TEXT  \
# 0   What role does best descrive your involvement ...
# 1                         {"ImportId":"QID96_4_TEXT"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 84                                                NaN
# 85                                                NaN
# 86                                                NaN
# 87                                                NaN
# 88                                                NaN
#
#                                Education                Gender  \
# 0   Highest level of education completed                Gender
# 1              {"ImportId":"QID97_TEXT"}  {"ImportId":"QID98"}
# 2                            Hs diploma                   Male
# 3                              Bachelors                Female
# 4                           High school                   Male
# ..                                   ...                   ...
# 84                           High school                  Male
# 85                              12 grade                  Male
# 86       3yrs community college(Nursing)                  Male
# 87                          High school                   Male
# 88                       College 2 years                Female
#
#                               Ethnicity  \
# 0           Ethnicity - Selected Choice
# 1                  {"ImportId":"QID99"}
# 2                                 White
# 3                 White,Hispanic/LatinX
# 4                                 White
# ..                                  ...
# 84  Native Hawaiian or Pacific Islander
# 85                                White
# 86                      Hispanic/LatinX
# 87                      Hispanic/LatinX
# 88            Black or African American
#
#                             Ethnicity_21_TEXT pic1_yes pic2_yes pic3_yes
# 0   Ethnicity - Other (Please specify) - Text        0        0        0
# 1                {"ImportId":"QID99_21_TEXT"}        0        0        0
# 2                                         NaN        2        3        3
# 3                                         NaN        2        3        4
# 4                                         NaN        1        2        1
# ..                                        ...      ...      ...      ...
# 84                                        NaN        1        1        0
# 85                                        NaN        1        4        1
# 86                                        NaN        1        4        2
# 87                                        NaN        3        3        1
# 88                                        NaN        2        4        1
#
# [89 rows x 215 columns]

# %%
# Rearranging the counts so every column is in reference to one picture

split_row = 78

vr_dsa = vr_data2[:split_row]
vr_dsb = vr_data2[split_row:]

# %%
#vr_dsa

# %%
#vr_dsb

# %%
warnings.filterwarnings('ignore')
vr_dsb['tem1'] = vr_dsb['pic1_yes']

# %%
warnings.filterwarnings('ignore')
vr_dsb['pic1_yes'] = vr_dsb['pic3_yes']

# %%
warnings.filterwarnings('ignore')
vr_dsb['tem2'] = vr_dsb['pic2_yes']

# %%
warnings.filterwarnings('ignore')
vr_dsb['pic2_yes'] = vr_dsb['tem1']

# %%
warnings.filterwarnings('ignore')
vr_dsb['pic3_yes'] = vr_dsb['tem2']

# %%
#vr_dsb

# %%
# Putting the dataframe into one
vr_df1 = pd.concat([vr_dsa, vr_dsb])

# %%
#vr_df1

# %%
# Cleaning the dataframe

columns_to_drop = ['tem1', 'tem2']
vr_data2c = vr_df1.drop(columns=columns_to_drop)

# %%
#vr_data2c

# %%
vr_data3 = vr_data2c.copy()

# %%
# Creating the hazard percentage for picture number one

vr_data3['perc_ident1'] = vr_data3['pic1_yes'] / 16

# %%
# Creating the hazard percentages for picture number two

vr_data3['perc_ident2'] = vr_data3['pic2_yes'] / 23

# %%
# Counting the hazard percentages for picture number three

vr_data3['perc_ident3'] = vr_data3['pic3_yes'] / 16

# %%
#vr_data3

# %%
cols_to_drop = ['pic1_yes', 'pic2_yes', 'pic3_yes']
vr_data3 = vr_data3.drop(cols_to_drop, axis=1)

# %%
vr_data3.to_csv('vrdata_3c', index = False)
